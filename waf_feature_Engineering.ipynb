# %% [markdown]
# <a href="https://colab.research.google.com/github/miniact/mangyaWAF/blob/master/mms_waf_feature_Engineering~mangesh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the main notebook performing all feature engineering
# The different steps are:
#
# Step1 - import dependencies
#
# Step2 - load payloads into memory
#
# Step3A - Feature engineering custom features

# %% [markdown]
# # Step 1 : import dependencies

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn
import string
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import learning_curve
from sklearn.decomposition import TruncatedSVD

# %% [markdown]
# # step 2: load data set

# %%
payloads = pd.read_csv("https://trello-attachments.s3.amazonaws.com/5ed2d4107c349c221194b608/5ed2d453f0e5a45bcd8cf16c/4265dd7f345df26845ccc5b7f82a7289/payloads.csv",index_col="index")
payloads.head(30)
# Out:
#                                                  payload  is_malicious  \
# index
# 0                                              37662577P           0.0
# 1                                               shirting           0.0
# 2                        &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                obeying           0.0
# 4                                              dictating           0.0
# 5                                                lafleur           0.0
# 6                                              capturers           0.0
# 7                                              8nca58z48           0.0
# 8                                             autocratic           0.0
# 9                                     grocery+warehouses           0.0
# 10                                               Danciel           0.0
# 11                                               Koressa           0.0
# 12                           bowie0%40showeb-handling.bi           0.0
# 13                                            Auque+Cote           0.0
# 14                                              broadest           0.0
# 15                                        Xaubet+Sorolla           0.0
# 16                                            vocational           0.0
# 17                                                 Yemen           0.0
# 18                                                 22584           0.0
# 19                               <BR SIZE="&{alert(1)}">           1.0
# 20                                             impaction           0.0
# 21     <button onclick="window.open('http://xss.cx/::...           1.0
# 22     <IFRAME SRC="javascript:alert(\'XSS\');"></IFR...           1.0
# 23                                                 03830           0.0
# 24                                             pineapple           0.0
# 25                                        La+Lora+11%2C+           0.0
# 26                                              Pittston           0.0
# 27                                               Aeriela           0.0
# 28                                              Brewster           0.0
# 29                                                doting           0.0
#
#       injection_type
# index
# 0              LEGAL
# 1              LEGAL
# 2                XSS
# 3              LEGAL
# 4              LEGAL
# 5              LEGAL
# 6              LEGAL
# 7              LEGAL
# 8              LEGAL
# 9              LEGAL
# 10             LEGAL
# 11             LEGAL
# 12             LEGAL
# 13             LEGAL
# 14             LEGAL
# 15             LEGAL
# 16             LEGAL
# 17             LEGAL
# 18             LEGAL
# 19               XSS
# 20             LEGAL
# 21               XSS
# 22               XSS
# 23             LEGAL
# 24             LEGAL
# 25             LEGAL
# 26             LEGAL
# 27             LEGAL
# 28             LEGAL
# 29             LEGAL

# %% [markdown]
# #Step3A - Feature engineering custom features
# *  length of payload
# *  number of non-printable characters in payload
# *  number of punctuation characters in payload
# *  the minimum byte value of payload
# *  the maximum byte value of payload
# *  the mean byte value of payload
# *  the standard deviation of payload byte values
# *  number of distinct bytes in payload
# *  number of SQL keywords in payload
# *  number of javascript keywords in payload

# %%
def plot_feature_distribution(features):

  """ 
  function to quickly genetrate graph  and describe about feature
  """
  print('Properties of feature: ' + features.name)
  print(features.describe())
  f, ax = plt.subplots(1, figsize=(10, 6))
  ax.hist(features, bins=features.max()-features.min()+1, normed=1)
  ax.set_xlabel('value')
  ax.set_ylabel('fraction')
    
  plt.show()

# %%
def create_feature_length(payloads):
  """
  function to create length feature
  """
  payloads['length'] = [len(str(row)) for row in payloads['payload'] ]
  return payloads

payloads = create_feature_length(payloads)
display(payloads.head())
#plot graph
plot_feature_distribution(payloads['length'])
# Out:
#                                payload  is_malicious injection_type  length
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
# Properties of feature: length
# count    110357.000000
# mean         16.559629
# std          32.108640
# min           1.000000
# 25%           6.000000
# 50%           9.000000
# 75%          14.000000
# max         974.000000
# Name: length, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 11>()
#       9 display(payloads.head())
#      10 #plot graph
# ---> 11 plot_feature_distribution(payloads['length'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
def create_feature_nonprintable(payloads):
  """ 
   function to find non- printable char in payload if present -->1 if absent --> 0
  """
  payloads['non-printable'] = [len([1 for letter in str(row) if letter not in string.printable]) for row in payloads['payload']]
  return payloads

payloads = create_feature_nonprintable(payloads)
display(payloads.head())

plot_feature_distribution(payloads['non-printable'])
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable
# index
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# Properties of feature: non-printable
# count    110357.000000
# mean          0.007412
# std           0.216736
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          30.000000
# Name: non-printable, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 11>()
#       8 payloads = create_feature_nonprintable(payloads)
#       9 display(payloads.head())
# ---> 11 plot_feature_distribution(payloads['non-printable'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
def create_feature_punchualchar(payloads):
  #adds new punctual cloumns with count of punctual characters in payload
  payloads['punctuation'] = [len([1 for letter in str(row) if letter in string.punctuation])  for row in payloads['payload']]
  return payloads

payloads = create_feature_punchualchar(payloads)
display(payloads.head())

plot_feature_distribution(payloads['punctuation'])
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation
# index
# 0                  0            0
# 1                  0            0
# 2                  0           11
# 3                  0            0
# 4                  0            0
# Properties of feature: punctuation
# count    110357.000000
# mean          2.363729
# std           9.771260
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         538.000000
# Name: punctuation, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 9>()
#       6 payloads = create_feature_punchualchar(payloads)
#       7 display(payloads.head())
# ----> 9 plot_feature_distribution(payloads['punctuation'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
# minimum byte value of payload
def create_feature_minbyte(payloads):
  payloads['min-byte'] = [min(bytearray(str(row),'utf-8')) for row in payloads['payload']]
  return payloads

payloads = create_feature_minbyte(payloads)
display(payloads.head())
plot_feature_distribution(payloads['min-byte'])
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte
# index
# 0                  0            0        50
# 1                  0            0       103
# 2                  0           11        37
# 3                  0            0        98
# 4                  0            0        97
# Properties of feature: min-byte
# count    110357.000000
# mean         71.225749
# std          26.545783
# min           9.000000
# 25%          48.000000
# 50%          75.000000
# 75%          97.000000
# max         125.000000
# Name: min-byte, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 8>()
#       6 payloads = create_feature_minbyte(payloads)
#       7 display(payloads.head())
# ----> 8 plot_feature_distribution(payloads['min-byte'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
#max byte feature# maximum byte value of payload
def create_feature_minbyte(payloads):
  payloads['max-byte'] = [max(bytearray(str(row),'utf-8')) for row in payloads['payload']]
  return payloads

payloads = create_feature_minbyte(payloads)
display(payloads.head())
plot_feature_distribution(payloads['max-byte'])
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte  max-byte
# index
# 0                  0            0        50        80
# 1                  0            0       103       116
# 2                  0           11        37       119
# 3                  0            0        98       121
# 4                  0            0        97       116
# Properties of feature: max-byte
# count    110357.000000
# mean        109.495166
# std          20.327684
# min          33.000000
# 25%         114.000000
# 50%         116.000000
# 75%         118.000000
# max         240.000000
# Name: max-byte, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 8>()
#       6 payloads = create_feature_minbyte(payloads)
#       7 display(payloads.head())
# ----> 8 plot_feature_distribution(payloads['max-byte'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
#mean byte value of payload
def create_feature_minbyte(payloads):
  payloads['mean-byte'] = [np.mean(bytearray(str(row),'utf-8')) for row in payloads['payload']]
  return payloads

payloads = create_feature_minbyte(payloads)
display(payloads.head())
plot_feature_distribution(payloads['mean-byte'].astype(int))
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte  max-byte   mean-byte
# index
# 0                  0            0        50        80   56.333333
# 1                  0            0       103       116  109.000000
# 2                  0           11        37       119   65.806452
# 3                  0            0        98       121  107.000000
# 4                  0            0        97       116  105.666667
# Properties of feature: mean-byte
# count    110357.000000
# mean         92.514041
# std          19.323046
# min          33.000000
# 25%          83.000000
# 50%         101.000000
# 75%         107.000000
# max         164.000000
# Name: mean-byte, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 8>()
#       6 payloads = create_feature_minbyte(payloads)
#       7 display(payloads.head())
# ----> 8 plot_feature_distribution(payloads['mean-byte'].astype(int))
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
#standard deviation of byte value of payload
def create_feature_minbyte(payloads):
  payloads['std-byte'] = [np.std(bytearray(str(row),'utf-8')) for row in payloads['payload']]
  return payloads

payloads = create_feature_minbyte(payloads)
display(payloads.head())
plot_feature_distribution(payloads['std-byte'].astype(int))
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte  max-byte   mean-byte   std-byte
# index
# 0                  0            0        50        80   56.333333   8.537499
# 1                  0            0       103       116  109.000000   5.049752
# 2                  0           11        37       119   65.806452  26.617263
# 3                  0            0        98       121  107.000000   7.151423
# 4                  0            0        97       116  105.666667   6.599663
# Properties of feature: std-byte
# count    110357.000000
# mean         12.155677
# std           9.201188
# min           0.000000
# 25%           5.000000
# 50%           7.000000
# 75%          20.000000
# max          75.000000
# Name: std-byte, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 8>()
#       6 payloads = create_feature_minbyte(payloads)
#       7 display(payloads.head())
# ----> 8 plot_feature_distribution(payloads['std-byte'].astype(int))
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
#distinct byte value of payload
def create_feature_minbyte(payloads):
  payloads['distinct-byte'] = [len(set(bytearray(str(row),'utf-8'))) for row in payloads['payload']]
  return payloads

payloads = create_feature_minbyte(payloads)
display(payloads.head())
plot_feature_distribution(payloads['distinct-byte'].astype(int))
# Out:
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte  max-byte   mean-byte   std-byte  \
# index
# 0                  0            0        50        80   56.333333   8.537499
# 1                  0            0       103       116  109.000000   5.049752
# 2                  0           11        37       119   65.806452  26.617263
# 3                  0            0        98       121  107.000000   7.151423
# 4                  0            0        97       116  105.666667   6.599663
#
#        distinct-byte
# index
# 0                  6
# 1                  7
# 2                 18
# 3                  7
# 4                  7
# Properties of feature: distinct-byte
# count    110357.000000
# mean          9.483078
# std           7.410805
# min           1.000000
# 25%           5.000000
# 50%           7.000000
# 75%          10.000000
# max          76.000000
# Name: distinct-byte, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 8>()
#       6 payloads = create_feature_minbyte(payloads)
#       7 display(payloads.head())
# ----> 8 plot_feature_distribution(payloads['distinct-byte'].astype(int))
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
#number of SQL keywords in payload
sql_keywords = pd.read_csv('https://trello-attachments.s3.amazonaws.com/5ed2d4107c349c221194b608/5ed2d453f0e5a45bcd8cf16c/435e639346787ce2b495a16e9f690ef5/SQLKeywords.txt', index_col=False)

def create_feature_sql_keywords(payloads):
    
    '''
    Feature
    Number of SQL keywords within payload
    '''
    payloads['sql-keywords'] = [ len([1 for keyword in sql_keywords['Keyword'] if str(keyword).lower() in str(row).lower()]) for row in payloads['payload']]
    return payloads

create_feature_sql_keywords(payloads)
display(type(sql_keywords))
display(payloads.head())
plot_feature_distribution(payloads['sql-keywords'])
# Out:
# pandas.core.frame.DataFrame
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte  max-byte   mean-byte   std-byte  \
# index
# 0                  0            0        50        80   56.333333   8.537499
# 1                  0            0       103       116  109.000000   5.049752
# 2                  0           11        37       119   65.806452  26.617263
# 3                  0            0        98       121  107.000000   7.151423
# 4                  0            0        97       116  105.666667   6.599663
#
#        distinct-byte  sql-keywords
# index
# 0                  6             0
# 1                  7             0
# 2                 18             0
# 3                  7             0
# 4                  7             0
# Properties of feature: sql-keywords
# count    110357.000000
# mean          0.196009
# std           0.671691
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          15.000000
# Name: sql-keywords, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [16], in <cell line: 16>()
#      14 display(type(sql_keywords))
#      15 display(payloads.head())
# ---> 16 plot_feature_distribution(payloads['sql-keywords'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %%
# javascript key word is presten or not in payload
js_keywords = pd.read_csv("https://trello-attachments.s3.amazonaws.com/5ed2d4107c349c221194b608/5ed2d453f0e5a45bcd8cf16c/dedc7eb9846a30c252cd950a0e2153d9/JavascriptKeywords.txt",index_col=False)
def create_feature_javascript_keywords(payloads):
  payloads['js-keywords'] = [len([1 for keyword in js_keywords['Keyword'] if str(keyword).lower() in str(row).lower()]) for row in payloads['payload']]
  return payloads
display(js_keywords)
payloads = create_feature_javascript_keywords(payloads)
display(payloads.head())
plot_feature_distribution(payloads['js-keywords'])
# Out:
#        Keyword
# 0     abstract
# 1    arguments
# 2       await*
# 3      boolean
# 4        break
# ..         ...
# 143   textarea
# 144        top
# 145   unescape
# 146    untaint
# 147     window
#
# [148 rows x 1 columns]
#                                payload  is_malicious injection_type  length  \
# index
# 0                            37662577P           0.0          LEGAL       9
# 1                             shirting           0.0          LEGAL       8
# 2      &kw=%27;alert%28%27XSS%27%29;//           1.0            XSS      31
# 3                              obeying           0.0          LEGAL       7
# 4                            dictating           0.0          LEGAL       9
#
#        non-printable  punctuation  min-byte  max-byte   mean-byte   std-byte  \
# index
# 0                  0            0        50        80   56.333333   8.537499
# 1                  0            0       103       116  109.000000   5.049752
# 2                  0           11        37       119   65.806452  26.617263
# 3                  0            0        98       121  107.000000   7.151423
# 4                  0            0        97       116  105.666667   6.599663
#
#        distinct-byte  sql-keywords  js-keywords
# index
# 0                  6             0            0
# 1                  7             0            1
# 2                 18             0            1
# 3                  7             0            1
# 4                  7             0            1
# Properties of feature: js-keywords
# count    110357.000000
# mean          0.354857
# std           0.821220
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          15.000000
# Name: js-keywords, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 9>()
#       7 payloads = create_feature_javascript_keywords(payloads)
#       8 display(payloads.head())
# ----> 9 plot_feature_distribution(payloads['js-keywords'])
#
# Input In [7], in plot_feature_distribution(features)
#       7 print(features.describe())
#       8 f, ax = plt.subplots(1, figsize=(10, 6))
# ----> 9 ax.hist(features, bins=features.max()-features.min()+1, normed=1)
#      10 ax.set_xlabel('value')
#      11 ax.set_ylabel('fraction')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6791, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6789 if patch:
#    6790     p = patch[0]
# -> 6791     p.update(kwargs)
#    6792     if lbl is not None:
#    6793         p.set_label(lbl)
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Rectangle' object has no property 'normed'

# %% [markdown]
# **Store all data in csv file for modeling**

# %%
payloads.to_csv("final-allpayload.csv",encoding='UTF-8')
payloads
# Out:
#                                                   payload  is_malicious  \
# index
# 0                                               37662577P           0.0
# 1                                                shirting           0.0
# 2                         &kw=%27;alert%28%27XSS%27%29;//           1.0
# 3                                                 obeying           0.0
# 4                                               dictating           0.0
# ...                                                   ...           ...
# 110355                                       needlessness           0.0
# 110356                                            Mary-Jo           0.0
# 110357                                          marshaled           0.0
# 110358                                   9553847952570755           0.0
# 110359  "><body language=vbs onload=window.location='d...           1.0
#
#        injection_type  length  non-printable  punctuation  min-byte  max-byte  \
# index
# 0               LEGAL       9              0            0        50        80
# 1               LEGAL       8              0            0       103       116
# 2                 XSS      31              0           11        37       119
# 3               LEGAL       7              0            0        98       121
# 4               LEGAL       9              0            0        97       116
# ...               ...     ...            ...          ...       ...       ...
# 110355          LEGAL      12              0            0       100       115
# 110356          LEGAL       7              0            1        45       121
# 110357          LEGAL       9              0            0        97       115
# 110358          LEGAL      16              0            0        48        57
# 110359            XSS     109              0           16        32       122
#
#          mean-byte   std-byte  distinct-byte  sql-keywords  js-keywords
# index
# 0        56.333333   8.537499              6             0            0
# 1       109.000000   5.049752              7             0            1
# 2        65.806452  26.617263             18             0            1
# 3       107.000000   7.151423              7             0            1
# 4       105.666667   6.599663              7             0            1
# ...            ...        ...            ...           ...          ...
# 110355  107.666667   6.209312              5             1            0
# 110356   91.285714  25.257046              7             0            0
# 110357  105.000000   6.463573              8             0            0
# 110358   53.375000   2.368412              8             0            0
# 110359   90.990826  24.773653             50             3            5
#
# [110357 rows x 13 columns]

# %% [markdown]
# **-->Testing For correlations between the dependent and independent variable**

# %%
payloads.corr()
# Out:
#                is_malicious    length  non-printable  punctuation  min-byte  \
# is_malicious       1.000000  0.503527       0.109038     0.545746 -0.437840
# length             0.503527  1.000000       0.054125     0.822890 -0.371302
# non-printable      0.109038  0.054125       1.000000     0.051506 -0.045852
# punctuation        0.545746  0.822890       0.051506     1.000000 -0.328024
# min-byte          -0.437840 -0.371302      -0.045852    -0.328024  1.000000
# max-byte           0.169479  0.120582       0.184621     0.102129  0.276576
# mean-byte         -0.194447 -0.171218       0.023385    -0.173458  0.731282
# std-byte           0.523487  0.400627       0.120833     0.363667 -0.716344
# distinct-byte      0.672833  0.764464       0.089188     0.596996 -0.560139
# sql-keywords       0.362440  0.515105       0.016287     0.374709 -0.194122
# js-keywords        0.484594  0.548591       0.036184     0.440164 -0.204792
#
#                max-byte  mean-byte  std-byte  distinct-byte  sql-keywords  \
# is_malicious   0.169479  -0.194447  0.523487       0.672833      0.362440
# length         0.120582  -0.171218  0.400627       0.764464      0.515105
# non-printable  0.184621   0.023385  0.120833       0.089188      0.016287
# punctuation    0.102129  -0.173458  0.363667       0.596996      0.374709
# min-byte       0.276576   0.731282 -0.716344      -0.560139     -0.194122
# max-byte       1.000000   0.770179  0.432612       0.261911      0.134943
# mean-byte      0.770179   1.000000 -0.143514      -0.172886     -0.030739
# std-byte       0.432612  -0.143514  1.000000       0.669620      0.265067
# distinct-byte  0.261911  -0.172886  0.669620       1.000000      0.497401
# sql-keywords   0.134943  -0.030739  0.265067       0.497401      1.000000
# js-keywords    0.203148   0.027468  0.312151       0.583256      0.557342
#
#                js-keywords
# is_malicious      0.484594
# length            0.548591
# non-printable     0.036184
# punctuation       0.440164
# min-byte         -0.204792
# max-byte          0.203148
# mean-byte         0.027468
# std-byte          0.312151
# distinct-byte     0.583256
# sql-keywords      0.557342
# js-keywords       1.000000

# %% [markdown]
# ***Function to Apply all custom feature engineering and gives a final dataset***

# %%
def create_features(payloads):
    features = create_feature_length(payloads)
    features = create_feature_non_printable_characters(features)
    features = create_feature_punctuation_characters(features)
    features = create_feature_max_byte_value(features)
    features = create_feature_min_byte_value(features)
    features = create_feature_mean_byte_value(features)
    features = create_feature_std_byte_value(features)
    features = create_feature_distinct_bytes(features)
    features = create_feature_sql_keywords(features)
    features = create_feature_javascript_keywords(features)
    del features['payload']

    return features
